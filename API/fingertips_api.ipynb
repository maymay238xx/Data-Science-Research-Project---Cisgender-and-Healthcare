# %%
#Import Relevant Libraries
# HTTP requests to call the API
import requests

# Data handling
import pandas as pd

# Plotting
import matplotlib.pyplot as plt

# %%
# Fingertips API wrapper
import fingertips_py as ftp

# %%
#Confirm API Connection

# %% [markdown]
# First explored the Fingertips API to identify available data profiles and understand how indicators are organised. Profiles group related public health metrics for easier discovery

# %%
dir(ftp)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'api_calls',
#  'area_data',
#  'deprivation_decile',
#  'get_age_from_id',
#  'get_age_id',
#  'get_all_ages',
#  'get_all_areas',
#  'get_all_areas_for_all_indicators',
#  'get_all_data_for_indicators',
#  'get_all_data_for_profile',
#  'get_all_profiles',
#  'get_all_sexes',
#  'get_all_value_notes',
#  'get_area_type_ids_for_profile',
#  'get_area_types_as_dict',
#  'get_area_types_for_profile',
#  'get_areas_for_area_type',
#  'get_data_by_indicator_ids',
#  'get_data_for_indicator_at_all_available_geographies',
#  'get_domains_in_profile',
#  'get_json',
#  'get_metadata',
#  'get_metadata_for_all_indicators',
#  'get_metadata_for_all_indicators_from_csv',
#  'get_metadata_for_domain_as_dataframe',
#  'get_metadata_for_indicator',
#  'get_metadata_for_indicator_as_dataframe',
#  'get_metadata_for_profile_as_dataframe',
#  'get_multiplier_and_calculation_for_indicator',
#  'get_profile_by_id',
#  'get_profile_by_name',
#  'get_sex_from_id',
#  'get_sex_id',
#  'get_value_note_id',
#  'make_request',
#  'metadata',
#  'retrieve_data']

# %%
available_profiles = ftp.get_all_profiles()

# %%
# Check what type it is
type(available_profiles)
# Out:
# dict

# %%
# Print the profile dictionary
available_profiles
# Out:
# {18: {'Id': 18,
#   'Name': 'Smoking Profile',
#   'Key': 'tobacco-control',
#   'GroupIds': [1938132885,
#    1938132886,
#    1938132900,
#    1938132887,
#    1938132888,
#    1938132889,
#    1938132890],
#   'GroupMetadata': [{'Id': 1938132885,
#     'Name': 'Key indicators',
#     'Sequence': 1,
#     'ProfileId': 18,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 22},
#      {'AreaTypeId': 15, 'IndicatorCount': 20},
#      {'AreaTypeId': 66, 'IndicatorCount': 2},
#      {'AreaTypeId': 221, 'IndicatorCount': 10},
#      {'AreaTypeId': 401, 'IndicatorCount': 18},
#      {'AreaTypeId': 402, 'IndicatorCount': 18},
#      {'AreaTypeId': 501, 'IndicatorCount': 18},
#      {'AreaTypeId': 502, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 10}]},
#    {'Id': 1938132886,
#     'Name': 'Smoking prevalence in adults',
#     'Sequence': 2,
#     'ProfileId': 18,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 26},
#      {'AreaTypeId': 15, 'IndicatorCount': 26},
#      {'AreaTypeId': 66, 'IndicatorCount': 20},
#      {'AreaTypeId': 221, 'IndicatorCount': 14},
#      {'AreaTypeId': 223, 'IndicatorCount': 6},
#      {'AreaTypeId': 401, 'IndicatorCount': 26},
#      {'AreaTypeId': 402, 'IndicatorCount': 26},
#      {'AreaTypeId': 501, 'IndicatorCount': 26},
#      {'AreaTypeId': 502, 'IndicatorCount': 26},
#      {'AreaTypeId': 15, 'IndicatorCount': 10}]},
#    {'Id': 1938132900,
#     'Name': 'Smoking prevalence in priority populations',
#     'Sequence': 3,
#     'ProfileId': 18,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 40},
#      {'AreaTypeId': 15, 'IndicatorCount': 40},
#      {'AreaTypeId': 66, 'IndicatorCount': 4},
#      {'AreaTypeId': 221, 'IndicatorCount': 6},
#      {'AreaTypeId': 401, 'IndicatorCount': 20},
#      {'AreaTypeId': 402, 'IndicatorCount': 32},
#      {'AreaTypeId': 501, 'IndicatorCount': 20},
#      {'AreaTypeId': 502, 'IndicatorCount': 32},
#      {'AreaTypeId': 15, 'IndicatorCount': 18}]},
#    {'Id': 1938132887,
#     'Name': 'Smoking related mortality',
#     'Sequence': 4,
#     'ProfileId': 18,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 24},
#      {'AreaTypeId': 15, 'IndicatorCount': 24},
#      {'AreaTypeId': 401, 'IndicatorCount': 6},
#      {'AreaTypeId': 402, 'IndicatorCount': 20},
#      {'AreaTypeId': 501, 'IndicatorCount': 6},
#      {'AreaTypeId': 502, 'IndicatorCount': 20},
#      {'AreaTypeId': 15, 'IndicatorCount': 10}]},
#    {'Id': 1938132888,
#     'Name': 'Smoking related ill health',
#     'Sequence': 5,
#     'ProfileId': 18,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 18},
#      {'AreaTypeId': 66, 'IndicatorCount': 2},
#      {'AreaTypeId': 221, 'IndicatorCount': 2},
#      {'AreaTypeId': 223, 'IndicatorCount': 2},
#      {'AreaTypeId': 401, 'IndicatorCount': 12},
#      {'AreaTypeId': 402, 'IndicatorCount': 16},
#      {'AreaTypeId': 501, 'IndicatorCount': 12},
#      {'AreaTypeId': 502, 'IndicatorCount': 16},
#      {'AreaTypeId': 15, 'IndicatorCount': 9}]},
#    {'Id': 1938132889,
#     'Name': 'Impact of smoking',
#     'Sequence': 6,
#     'ProfileId': 18,
#     'DataAvailable': []},
#    {'Id': 1938132890,
#     'Name': 'Smoking quitters',
#     'Sequence': 7,
#     'ProfileId': 18,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 14},
#      {'AreaTypeId': 15, 'IndicatorCount': 14},
#      {'AreaTypeId': 402, 'IndicatorCount': 14},
#      {'AreaTypeId': 502, 'IndicatorCount': 14},
#      {'AreaTypeId': 15, 'IndicatorCount': 7}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'Reports',
#    'AreaProfile',
#    'CompareIndicators',
#    'Population',
#    'Definitions',
#    'Inequalities',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': True,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': True,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  19: {'Id': 19,
#   'Name': 'Public Health Outcomes Framework',
#   'Key': 'public-health-outcomes-framework',
#   'GroupIds': [1000049, 1000041, 1000042, 1000043, 1000044, 1938132983],
#   'GroupMetadata': [{'Id': 1000049,
#     'Name': 'A. Overarching indicators',
#     'Sequence': 1,
#     'ProfileId': 19,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 40},
#      {'AreaTypeId': 15, 'IndicatorCount': 44},
#      {'AreaTypeId': 221, 'IndicatorCount': 8},
#      {'AreaTypeId': 223, 'IndicatorCount': 8},
#      {'AreaTypeId': 301, 'IndicatorCount': 24},
#      {'AreaTypeId': 302, 'IndicatorCount': 38},
#      {'AreaTypeId': 501, 'IndicatorCount': 24},
#      {'AreaTypeId': 502, 'IndicatorCount': 44},
#      {'AreaTypeId': 15, 'IndicatorCount': 10}]},
#    {'Id': 1000041,
#     'Name': 'B. Wider determinants of health',
#     'Sequence': 2,
#     'ProfileId': 19,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 72},
#      {'AreaTypeId': 15, 'IndicatorCount': 72},
#      {'AreaTypeId': 221, 'IndicatorCount': 32},
#      {'AreaTypeId': 223, 'IndicatorCount': 32},
#      {'AreaTypeId': 301, 'IndicatorCount': 36},
#      {'AreaTypeId': 302, 'IndicatorCount': 72},
#      {'AreaTypeId': 501, 'IndicatorCount': 36},
#      {'AreaTypeId': 502, 'IndicatorCount': 72},
#      {'AreaTypeId': 15, 'IndicatorCount': 36}]},
#    {'Id': 1000042,
#     'Name': 'C. Health improvement',
#     'Sequence': 3,
#     'ProfileId': 19,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 130},
#      {'AreaTypeId': 15, 'IndicatorCount': 130},
#      {'AreaTypeId': 221, 'IndicatorCount': 62},
#      {'AreaTypeId': 223, 'IndicatorCount': 50},
#      {'AreaTypeId': 301, 'IndicatorCount': 72},
#      {'AreaTypeId': 302, 'IndicatorCount': 110},
#      {'AreaTypeId': 501, 'IndicatorCount': 72},
#      {'AreaTypeId': 502, 'IndicatorCount': 110},
#      {'AreaTypeId': 15, 'IndicatorCount': 63}]},
#    {'Id': 1000043,
#     'Name': 'D. Health protection',
#     'Sequence': 4,
#     'ProfileId': 19,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 72},
#      {'AreaTypeId': 15, 'IndicatorCount': 72},
#      {'AreaTypeId': 221, 'IndicatorCount': 64},
#      {'AreaTypeId': 223, 'IndicatorCount': 26},
#      {'AreaTypeId': 301, 'IndicatorCount': 18},
#      {'AreaTypeId': 302, 'IndicatorCount': 72},
#      {'AreaTypeId': 501, 'IndicatorCount': 18},
#      {'AreaTypeId': 502, 'IndicatorCount': 72},
#      {'AreaTypeId': 15, 'IndicatorCount': 33}]},
#    {'Id': 1000044,
#     'Name': 'E. Healthcare and premature mortality',
#     'Sequence': 5,
#     'ProfileId': 19,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 70},
#      {'AreaTypeId': 15, 'IndicatorCount': 72},
#      {'AreaTypeId': 221, 'IndicatorCount': 60},
#      {'AreaTypeId': 223, 'IndicatorCount': 60},
#      {'AreaTypeId': 301, 'IndicatorCount': 50},
#      {'AreaTypeId': 302, 'IndicatorCount': 62},
#      {'AreaTypeId': 501, 'IndicatorCount': 50},
#      {'AreaTypeId': 502, 'IndicatorCount': 62},
#      {'AreaTypeId': 15, 'IndicatorCount': 26}]},
#    {'Id': 1938132983,
#     'Name': 'Supporting information',
#     'Sequence': 6,
#     'ProfileId': 19,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 10},
#      {'AreaTypeId': 221, 'IndicatorCount': 6},
#      {'AreaTypeId': 223, 'IndicatorCount': 6},
#      {'AreaTypeId': 301, 'IndicatorCount': 10},
#      {'AreaTypeId': 302, 'IndicatorCount': 10},
#      {'AreaTypeId': 501, 'IndicatorCount': 10},
#      {'AreaTypeId': 502, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 5}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'Reports',
#    'AreaProfile',
#    'CompareIndicators',
#    'Population',
#    'Definitions',
#    'Inequalities',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': True,
#   'StartValueAxisFromZero': True,
#   'IsChangeFromPreviousPeriodShown': True,
#   'DefaultAreaTypeId': 502,
#   'DefaultTabId': 3,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  20: {'Id': 20,
#   'Name': 'National General Practice Profiles',
#   'Key': 'general-practice',
#   'GroupIds': [2000005,
#    1938132829,
#    3000008,
#    3000007,
#    3000009,
#    3000010,
#    2000002,
#    1938133477,
#    2000003,
#    2000004,
#    2000006,
#    1938132970,
#    1938133380],
#   'GroupMetadata': [{'Id': 2000005,
#     'Name': 'Practice summary',
#     'Sequence': 1,
#     'ProfileId': 20,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 18},
#      {'AreaTypeId': 66, 'IndicatorCount': 18},
#      {'AreaTypeId': 204, 'IndicatorCount': 18},
#      {'AreaTypeId': 221, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 4}]},
#    {'Id': 1938132829,
#     'Name': 'Cancer',
#     'Sequence': 2,
#     'ProfileId': 20,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 12},
#      {'AreaTypeId': 66, 'IndicatorCount': 12},
#      {'AreaTypeId': 204, 'IndicatorCount': 12},
#      {'AreaTypeId': 221, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 6}]},
#    {'Id': 3000008,
#     'Name': 'CVD - Coronary Heart Disease',
#     'Sequence': 3,
#     'ProfileId': 20,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 10},
#      {'AreaTypeId': 66, 'IndicatorCount': 10},
#      {'AreaTypeId': 204, 'IndicatorCount': 10},
#      {'AreaTypeId': 221, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 5}]},
#    {'Id': 3000007,
#     'Name': 'CVD - Stroke and TIA',
#     'Sequence': 4,
#     'ProfileId': 20,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 10},
#      {'AreaTypeId': 66, 'IndicatorCount': 10},
#      {'AreaTypeId': 204, 'IndicatorCount': 10},
#      {'AreaTypeId': 221, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 5}]},
#    {'Id': 3000009,
#     'Name': 'CVD - Heart Failure and Atrial Fibrillation',
#     'Sequence': 5,
#     'ProfileId': 20,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 18},
#      {'AreaTypeId': 66, 'IndicatorCount': 18},
#      {'AreaTypeId': 204, 'IndicatorCount': 18},
#      {'AreaTypeId': 221, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 9}]},
#    {'Id': 3000010,
#     'Name': 'CVD - Risk Factors for CVD',
#     'Sequence': 6,
#     'ProfileId': 20,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 22},
#      {'AreaTypeId': 15, 'IndicatorCount': 22},
#      {'AreaTypeId': 66, 'IndicatorCount': 22},
#      {'AreaTypeId': 204, 'IndicatorCount': 22},
#      {'AreaTypeId': 221, 'IndicatorCount': 22},
#      {'AreaTypeId': 15, 'IndicatorCount': 11}]},
#    {'Id': 2000002,
#     'Name': 'Diabetes',
#     'Sequence': 7,
#     'ProfileId': 20,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 26},
#      {'AreaTypeId': 15, 'IndicatorCount': 26},
#      {'AreaTypeId': 66, 'IndicatorCount': 26},
#      {'AreaTypeId': 204, 'IndicatorCount': 26},
#      {'AreaTypeId': 221, 'IndicatorCount': 26},
#      {'AreaTypeId': 15, 'IndicatorCount': 13}]},
#    {'Id': 1938133477,
#     'Name': 'GP patient survey',
#     'Sequence': 8,
#     'ProfileId': 20,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 38},
#      {'AreaTypeId': 15, 'IndicatorCount': 38},
#      {'AreaTypeId': 66, 'IndicatorCount': 38},
#      {'AreaTypeId': 204, 'IndicatorCount': 38},
#      {'AreaTypeId': 221, 'IndicatorCount': 38},
#      {'AreaTypeId': 15, 'IndicatorCount': 19}]},
#    {'Id': 2000003,
#     'Name': 'Mental Health',
#     'Sequence': 9,
#     'ProfileId': 20,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 28},
#      {'AreaTypeId': 15, 'IndicatorCount': 28},
#      {'AreaTypeId': 66, 'IndicatorCount': 28},
#      {'AreaTypeId': 204, 'IndicatorCount': 28},
#      {'AreaTypeId': 221, 'IndicatorCount': 28},
#      {'AreaTypeId': 15, 'IndicatorCount': 14}]},
#    {'Id': 2000004,
#     'Name': 'QOF prevalences',
#     'Sequence': 10,
#     'ProfileId': 20,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 46},
#      {'AreaTypeId': 15, 'IndicatorCount': 46},
#      {'AreaTypeId': 66, 'IndicatorCount': 46},
#      {'AreaTypeId': 204, 'IndicatorCount': 46},
#      {'AreaTypeId': 221, 'IndicatorCount': 46},
#      {'AreaTypeId': 15, 'IndicatorCount': 23}]},
#    {'Id': 2000006,
#     'Name': 'Respiratory Disease',
#     'Sequence': 11,
#     'ProfileId': 20,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 24},
#      {'AreaTypeId': 15, 'IndicatorCount': 24},
#      {'AreaTypeId': 66, 'IndicatorCount': 24},
#      {'AreaTypeId': 204, 'IndicatorCount': 24},
#      {'AreaTypeId': 221, 'IndicatorCount': 24},
#      {'AreaTypeId': 15, 'IndicatorCount': 12}]},
#    {'Id': 1938132970,
#     'Name': 'AMR Local Indicators',
#     'Sequence': 12,
#     'ProfileId': 20,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 6},
#      {'AreaTypeId': 15, 'IndicatorCount': 6},
#      {'AreaTypeId': 66, 'IndicatorCount': 6},
#      {'AreaTypeId': 204, 'IndicatorCount': 6},
#      {'AreaTypeId': 221, 'IndicatorCount': 6},
#      {'AreaTypeId': 15, 'IndicatorCount': 3}]},
#    {'Id': 1938133380,
#     'Name': 'Vaccinations',
#     'Sequence': 13,
#     'ProfileId': 20,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 8},
#      {'AreaTypeId': 66, 'IndicatorCount': 8},
#      {'AreaTypeId': 204, 'IndicatorCount': 8},
#      {'AreaTypeId': 221, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 4}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'CompareIndicators',
#    'Population',
#    'Definitions',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': True,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 7,
#   'DefaultTabId': 8,
#   'IgnoredSpineChartAreas': None,
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  21: {'Id': 21,
#   'Name': 'National General Practice Profiles (supporting indicators)',
#   'Key': 'practice-profiles-supporting-indicators',
#   'GroupIds': [1200006, 1938133447],
#   'GroupMetadata': [{'Id': 1200006,
#     'Name': 'National GP Profiles - Supporting Indicators',
#     'Sequence': 1,
#     'ProfileId': 21,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 16},
#      {'AreaTypeId': 66, 'IndicatorCount': 8},
#      {'AreaTypeId': 204, 'IndicatorCount': 10},
#      {'AreaTypeId': 221, 'IndicatorCount': 16},
#      {'AreaTypeId': 15, 'IndicatorCount': 10}]},
#    {'Id': 1938133447,
#     'Name': 'Auto update 2',
#     'Sequence': 2,
#     'ProfileId': 21,
#     'DataAvailable': [{'AreaTypeId': 15, 'IndicatorCount': 6},
#      {'AreaTypeId': 15, 'IndicatorCount': 3}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'Definitions',
#    'Download'],
#   'HasRecentTrends': False,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': False},
#  26: {'Id': 26,
#   'Name': 'Local Authority Health Profiles',
#   'Key': 'health-profiles',
#   'GroupIds': [1938132696,
#    1938132695,
#    1938132694,
#    8000073,
#    1938133217,
#    3007000,
#    1938133216,
#    1938132701,
#    1938132974],
#   'GroupMetadata': [{'Id': 1938132696,
#     'Name': 'Life expectancy and causes of death',
#     'Sequence': 1,
#     'ProfileId': 26,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 16},
#      {'AreaTypeId': 15, 'IndicatorCount': 16},
#      {'AreaTypeId': 301, 'IndicatorCount': 16},
#      {'AreaTypeId': 302, 'IndicatorCount': 16},
#      {'AreaTypeId': 501, 'IndicatorCount': 16},
#      {'AreaTypeId': 502, 'IndicatorCount': 16},
#      {'AreaTypeId': 15, 'IndicatorCount': 5}]},
#    {'Id': 1938132695,
#     'Name': 'Injuries and ill health',
#     'Sequence': 2,
#     'ProfileId': 26,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 12},
#      {'AreaTypeId': 301, 'IndicatorCount': 12},
#      {'AreaTypeId': 302, 'IndicatorCount': 12},
#      {'AreaTypeId': 501, 'IndicatorCount': 12},
#      {'AreaTypeId': 502, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 6}]},
#    {'Id': 1938132694,
#     'Name': 'Behavioural risk factors',
#     'Sequence': 3,
#     'ProfileId': 26,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 10},
#      {'AreaTypeId': 301, 'IndicatorCount': 10},
#      {'AreaTypeId': 302, 'IndicatorCount': 10},
#      {'AreaTypeId': 501, 'IndicatorCount': 10},
#      {'AreaTypeId': 502, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 5}]},
#    {'Id': 8000073,
#     'Name': 'Child health',
#     'Sequence': 4,
#     'ProfileId': 26,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 8},
#      {'AreaTypeId': 301, 'IndicatorCount': 8},
#      {'AreaTypeId': 302, 'IndicatorCount': 8},
#      {'AreaTypeId': 501, 'IndicatorCount': 8},
#      {'AreaTypeId': 502, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 4}]},
#    {'Id': 1938133217,
#     'Name': 'Inequalities',
#     'Sequence': 5,
#     'ProfileId': 26,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 8},
#      {'AreaTypeId': 301, 'IndicatorCount': 8},
#      {'AreaTypeId': 302, 'IndicatorCount': 8},
#      {'AreaTypeId': 501, 'IndicatorCount': 8},
#      {'AreaTypeId': 502, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 3}]},
#    {'Id': 3007000,
#     'Name': 'Wider determinants of health',
#     'Sequence': 6,
#     'ProfileId': 26,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 12},
#      {'AreaTypeId': 301, 'IndicatorCount': 12},
#      {'AreaTypeId': 302, 'IndicatorCount': 12},
#      {'AreaTypeId': 501, 'IndicatorCount': 12},
#      {'AreaTypeId': 502, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 6}]},
#    {'Id': 1938133216,
#     'Name': 'Health protection',
#     'Sequence': 7,
#     'ProfileId': 26,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 6},
#      {'AreaTypeId': 15, 'IndicatorCount': 6},
#      {'AreaTypeId': 301, 'IndicatorCount': 6},
#      {'AreaTypeId': 302, 'IndicatorCount': 6},
#      {'AreaTypeId': 501, 'IndicatorCount': 6},
#      {'AreaTypeId': 502, 'IndicatorCount': 6},
#      {'AreaTypeId': 15, 'IndicatorCount': 3}]},
#    {'Id': 1938132701,
#     'Name': 'All indicators',
#     'Sequence': 8,
#     'ProfileId': 26,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 72},
#      {'AreaTypeId': 15, 'IndicatorCount': 72},
#      {'AreaTypeId': 301, 'IndicatorCount': 72},
#      {'AreaTypeId': 302, 'IndicatorCount': 72},
#      {'AreaTypeId': 501, 'IndicatorCount': 72},
#      {'AreaTypeId': 502, 'IndicatorCount': 72},
#      {'AreaTypeId': 15, 'IndicatorCount': 32}]},
#    {'Id': 1938132974,
#     'Name': 'Supporting information',
#     'Sequence': 9,
#     'ProfileId': 26,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 8},
#      {'AreaTypeId': 301, 'IndicatorCount': 8},
#      {'AreaTypeId': 302, 'IndicatorCount': 8},
#      {'AreaTypeId': 501, 'IndicatorCount': 8},
#      {'AreaTypeId': 502, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 4}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'Reports',
#    'AreaProfile',
#    'CompareIndicators',
#    'Population',
#    'Definitions',
#    'Inequalities',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': True,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': True,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': None,
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  29: {'Id': 29,
#   'Name': 'Respiratory disease',
#   'Key': 'respiratory-disease',
#   'GroupIds': [8000003,
#    1938133427,
#    8000008,
#    8000009,
#    1938133345,
#    8000005,
#    1938133300],
#   'GroupMetadata': [{'Id': 8000003,
#     'Name': 'Key indicators',
#     'Sequence': 1,
#     'ProfileId': 29,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 38},
#      {'AreaTypeId': 15, 'IndicatorCount': 48},
#      {'AreaTypeId': 66, 'IndicatorCount': 14},
#      {'AreaTypeId': 221, 'IndicatorCount': 46},
#      {'AreaTypeId': 223, 'IndicatorCount': 46},
#      {'AreaTypeId': 501, 'IndicatorCount': 30},
#      {'AreaTypeId': 502, 'IndicatorCount': 36},
#      {'AreaTypeId': 15, 'IndicatorCount': 16}]},
#    {'Id': 1938133427,
#     'Name': 'Respiratory disease',
#     'Sequence': 2,
#     'ProfileId': 29,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 36},
#      {'AreaTypeId': 15, 'IndicatorCount': 38},
#      {'AreaTypeId': 66, 'IndicatorCount': 2},
#      {'AreaTypeId': 221, 'IndicatorCount': 38},
#      {'AreaTypeId': 223, 'IndicatorCount': 38},
#      {'AreaTypeId': 501, 'IndicatorCount': 36},
#      {'AreaTypeId': 502, 'IndicatorCount': 36},
#      {'AreaTypeId': 15, 'IndicatorCount': 4}]},
#    {'Id': 8000008,
#     'Name': 'COPD',
#     'Sequence': 3,
#     'ProfileId': 29,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 36},
#      {'AreaTypeId': 66, 'IndicatorCount': 20},
#      {'AreaTypeId': 221, 'IndicatorCount': 22},
#      {'AreaTypeId': 223, 'IndicatorCount': 22},
#      {'AreaTypeId': 501, 'IndicatorCount': 16},
#      {'AreaTypeId': 502, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 9}]},
#    {'Id': 8000009,
#     'Name': 'Asthma',
#     'Sequence': 4,
#     'ProfileId': 29,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 14},
#      {'AreaTypeId': 66, 'IndicatorCount': 8},
#      {'AreaTypeId': 221, 'IndicatorCount': 14},
#      {'AreaTypeId': 223, 'IndicatorCount': 14},
#      {'AreaTypeId': 501, 'IndicatorCount': 6},
#      {'AreaTypeId': 502, 'IndicatorCount': 6},
#      {'AreaTypeId': 15, 'IndicatorCount': 6}]},
#    {'Id': 1938133345,
#     'Name': 'Pneumonia',
#     'Sequence': 5,
#     'ProfileId': 29,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 12},
#      {'AreaTypeId': 66, 'IndicatorCount': 4},
#      {'AreaTypeId': 221, 'IndicatorCount': 12},
#      {'AreaTypeId': 223, 'IndicatorCount': 12},
#      {'AreaTypeId': 501, 'IndicatorCount': 4},
#      {'AreaTypeId': 502, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 4}]},
#    {'Id': 8000005,
#     'Name': 'Risk Factors',
#     'Sequence': 6,
#     'ProfileId': 29,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 18},
#      {'AreaTypeId': 66, 'IndicatorCount': 8},
#      {'AreaTypeId': 221, 'IndicatorCount': 8},
#      {'AreaTypeId': 223, 'IndicatorCount': 8},
#      {'AreaTypeId': 401, 'IndicatorCount': 14},
#      {'AreaTypeId': 402, 'IndicatorCount': 14},
#      {'AreaTypeId': 501, 'IndicatorCount': 10},
#      {'AreaTypeId': 502, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 9}]},
#    {'Id': 1938133300,
#     'Name': 'Other',
#     'Sequence': 7,
#     'ProfileId': 29,
#     'DataAvailable': [{'AreaTypeId': 15, 'IndicatorCount': 4},
#      {'AreaTypeId': 66, 'IndicatorCount': 4},
#      {'AreaTypeId': 221, 'IndicatorCount': 4},
#      {'AreaTypeId': 223, 'IndicatorCount': 4},
#      {'AreaTypeId': 15, 'IndicatorCount': 2}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'CompareIndicators',
#    'Population',
#    'Definitions',
#    'Inequalities',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': False,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': True,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': None,
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  30: {'Id': 30,
#   'Name': 'Health Protection',
#   'Key': 'health-protection',
#   'GroupIds': [1938133433,
#    1938133209,
#    1938132804,
#    1938133210,
#    1938133211,
#    1938133212,
#    1938133214,
#    1938132818,
#    1938133434],
#   'GroupMetadata': [{'Id': 1938133433,
#     'Name': 'Key Indicators',
#     'Sequence': 1,
#     'ProfileId': 30,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 38},
#      {'AreaTypeId': 15, 'IndicatorCount': 38},
#      {'AreaTypeId': 301, 'IndicatorCount': 38},
#      {'AreaTypeId': 302, 'IndicatorCount': 38},
#      {'AreaTypeId': 401, 'IndicatorCount': 38},
#      {'AreaTypeId': 402, 'IndicatorCount': 40},
#      {'AreaTypeId': 501, 'IndicatorCount': 38},
#      {'AreaTypeId': 502, 'IndicatorCount': 38},
#      {'AreaTypeId': 15, 'IndicatorCount': 20}]},
#    {'Id': 1938133209,
#     'Name': 'Gastrointestinal infection',
#     'Sequence': 2,
#     'ProfileId': 30,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 26},
#      {'AreaTypeId': 15, 'IndicatorCount': 24},
#      {'AreaTypeId': 301, 'IndicatorCount': 22},
#      {'AreaTypeId': 302, 'IndicatorCount': 24},
#      {'AreaTypeId': 401, 'IndicatorCount': 20},
#      {'AreaTypeId': 402, 'IndicatorCount': 26},
#      {'AreaTypeId': 501, 'IndicatorCount': 24},
#      {'AreaTypeId': 502, 'IndicatorCount': 26},
#      {'AreaTypeId': 15, 'IndicatorCount': 13}]},
#    {'Id': 1938132804,
#     'Name': 'Immunisation & childhood vaccine preventable diseases',
#     'Sequence': 3,
#     'ProfileId': 30,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 66},
#      {'AreaTypeId': 15, 'IndicatorCount': 42},
#      {'AreaTypeId': 301, 'IndicatorCount': 60},
#      {'AreaTypeId': 302, 'IndicatorCount': 62},
#      {'AreaTypeId': 401, 'IndicatorCount': 12},
#      {'AreaTypeId': 402, 'IndicatorCount': 60},
#      {'AreaTypeId': 501, 'IndicatorCount': 60},
#      {'AreaTypeId': 502, 'IndicatorCount': 64},
#      {'AreaTypeId': 15, 'IndicatorCount': 33}]},
#    {'Id': 1938133210,
#     'Name': 'Respiratory infection',
#     'Sequence': 4,
#     'ProfileId': 30,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 24},
#      {'AreaTypeId': 15, 'IndicatorCount': 24},
#      {'AreaTypeId': 301, 'IndicatorCount': 22},
#      {'AreaTypeId': 302, 'IndicatorCount': 22},
#      {'AreaTypeId': 401, 'IndicatorCount': 22},
#      {'AreaTypeId': 402, 'IndicatorCount': 22},
#      {'AreaTypeId': 501, 'IndicatorCount': 22},
#      {'AreaTypeId': 502, 'IndicatorCount': 22},
#      {'AreaTypeId': 15, 'IndicatorCount': 12}]},
#    {'Id': 1938133211,
#     'Name': 'Hepatitis',
#     'Sequence': 5,
#     'ProfileId': 30,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 16},
#      {'AreaTypeId': 15, 'IndicatorCount': 16},
#      {'AreaTypeId': 301, 'IndicatorCount': 16},
#      {'AreaTypeId': 302, 'IndicatorCount': 16},
#      {'AreaTypeId': 401, 'IndicatorCount': 16},
#      {'AreaTypeId': 402, 'IndicatorCount': 16},
#      {'AreaTypeId': 501, 'IndicatorCount': 16},
#      {'AreaTypeId': 502, 'IndicatorCount': 16},
#      {'AreaTypeId': 15, 'IndicatorCount': 8}]},
#    {'Id': 1938133212,
#     'Name': 'Sexually transmitted infections & HIV',
#     'Sequence': 6,
#     'ProfileId': 30,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 44},
#      {'AreaTypeId': 15, 'IndicatorCount': 44},
#      {'AreaTypeId': 301, 'IndicatorCount': 44},
#      {'AreaTypeId': 302, 'IndicatorCount': 48},
#      {'AreaTypeId': 401, 'IndicatorCount': 44},
#      {'AreaTypeId': 402, 'IndicatorCount': 50},
#      {'AreaTypeId': 501, 'IndicatorCount': 2},
#      {'AreaTypeId': 502, 'IndicatorCount': 60},
#      {'AreaTypeId': 15, 'IndicatorCount': 30}]},
#    {'Id': 1938133214,
#     'Name': 'Health care associated infection',
#     'Sequence': 7,
#     'ProfileId': 30,
#     'DataAvailable': [{'AreaTypeId': 15, 'IndicatorCount': 2},
#      {'AreaTypeId': 402, 'IndicatorCount': 2},
#      {'AreaTypeId': 15, 'IndicatorCount': 1}]},
#    {'Id': 1938132818,
#     'Name': 'Non-infectious environmental hazards',
#     'Sequence': 8,
#     'ProfileId': 30,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 2},
#      {'AreaTypeId': 15, 'IndicatorCount': 2},
#      {'AreaTypeId': 301, 'IndicatorCount': 2},
#      {'AreaTypeId': 302, 'IndicatorCount': 2},
#      {'AreaTypeId': 401, 'IndicatorCount': 2},
#      {'AreaTypeId': 402, 'IndicatorCount': 2},
#      {'AreaTypeId': 501, 'IndicatorCount': 2},
#      {'AreaTypeId': 502, 'IndicatorCount': 2},
#      {'AreaTypeId': 15, 'IndicatorCount': 1}]},
#    {'Id': 1938133434,
#     'Name': 'Other',
#     'Sequence': 9,
#     'ProfileId': 30,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 12},
#      {'AreaTypeId': 301, 'IndicatorCount': 12},
#      {'AreaTypeId': 302, 'IndicatorCount': 12},
#      {'AreaTypeId': 401, 'IndicatorCount': 12},
#      {'AreaTypeId': 402, 'IndicatorCount': 12},
#      {'AreaTypeId': 501, 'IndicatorCount': 12},
#      {'AreaTypeId': 502, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 4}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'Reports',
#    'AreaProfile',
#    'CompareIndicators',
#    'Population',
#    'Definitions',
#    'Inequalities',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': False,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': True,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': None,
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  32: {'Id': 32,
#   'Name': 'Obesity, physical activity and nutrition',
#   'Key': 'obesity-physical-activity-nutrition',
#   'GroupIds': [8000011,
#    1938133288,
#    1938133441,
#    1938133435,
#    8000022,
#    1938133219,
#    1938133368,
#    1938133448,
#    1938133449],
#   'GroupMetadata': [{'Id': 8000011,
#     'Name': 'Child BMI categories',
#     'Sequence': 1,
#     'ProfileId': 32,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 28},
#      {'AreaTypeId': 15, 'IndicatorCount': 28},
#      {'AreaTypeId': 66, 'IndicatorCount': 24},
#      {'AreaTypeId': 221, 'IndicatorCount': 24},
#      {'AreaTypeId': 501, 'IndicatorCount': 28},
#      {'AreaTypeId': 502, 'IndicatorCount': 28},
#      {'AreaTypeId': 15, 'IndicatorCount': 14}]},
#    {'Id': 1938133288,
#     'Name': 'Child BMI categories small area data',
#     'Sequence': 2,
#     'ProfileId': 32,
#     'DataAvailable': [{'AreaTypeId': 3, 'IndicatorCount': 8},
#      {'AreaTypeId': 6, 'IndicatorCount': 8},
#      {'AreaTypeId': 8, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 8},
#      {'AreaTypeId': 501, 'IndicatorCount': 8},
#      {'AreaTypeId': 502, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 4}]},
#    {'Id': 1938133441,
#     'Name': 'Child BMI tracking',
#     'Sequence': 3,
#     'ProfileId': 32,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 4},
#      {'AreaTypeId': 15, 'IndicatorCount': 4},
#      {'AreaTypeId': 501, 'IndicatorCount': 4},
#      {'AreaTypeId': 502, 'IndicatorCount': 4},
#      {'AreaTypeId': 15, 'IndicatorCount': 2}]},
#    {'Id': 1938133435,
#     'Name': 'Child height',
#     'Sequence': 4,
#     'ProfileId': 32,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 12},
#      {'AreaTypeId': 66, 'IndicatorCount': 12},
#      {'AreaTypeId': 221, 'IndicatorCount': 12},
#      {'AreaTypeId': 501, 'IndicatorCount': 12},
#      {'AreaTypeId': 502, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 6}]},
#    {'Id': 8000022,
#     'Name': 'Child measurement data quality (NCMP)',
#     'Sequence': 5,
#     'ProfileId': 32,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 14},
#      {'AreaTypeId': 15, 'IndicatorCount': 16},
#      {'AreaTypeId': 501, 'IndicatorCount': 14},
#      {'AreaTypeId': 502, 'IndicatorCount': 16},
#      {'AreaTypeId': 15, 'IndicatorCount': 8}]},
#    {'Id': 1938133219,
#     'Name': 'Physical activity',
#     'Sequence': 6,
#     'ProfileId': 32,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 10},
#      {'AreaTypeId': 302, 'IndicatorCount': 2},
#      {'AreaTypeId': 501, 'IndicatorCount': 8},
#      {'AreaTypeId': 502, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 6}]},
#    {'Id': 1938133368,
#     'Name': 'Adult obesity',
#     'Sequence': 7,
#     'ProfileId': 32,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 8},
#      {'AreaTypeId': 66, 'IndicatorCount': 4},
#      {'AreaTypeId': 221, 'IndicatorCount': 6},
#      {'AreaTypeId': 501, 'IndicatorCount': 4},
#      {'AreaTypeId': 502, 'IndicatorCount': 6},
#      {'AreaTypeId': 15, 'IndicatorCount': 4}]},
#    {'Id': 1938133448,
#     'Name': 'Diet and nutrition',
#     'Sequence': 8,
#     'ProfileId': 32,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 6},
#      {'AreaTypeId': 15, 'IndicatorCount': 6},
#      {'AreaTypeId': 301, 'IndicatorCount': 2},
#      {'AreaTypeId': 501, 'IndicatorCount': 4},
#      {'AreaTypeId': 502, 'IndicatorCount': 4},
#      {'AreaTypeId': 15, 'IndicatorCount': 3}]},
#    {'Id': 1938133449,
#     'Name': 'Contextual indicators',
#     'Sequence': 9,
#     'ProfileId': 32,
#     'DataAvailable': [{'AreaTypeId': 501, 'IndicatorCount': 2},
#      {'AreaTypeId': 502, 'IndicatorCount': 2},
#      {'AreaTypeId': 15, 'IndicatorCount': 1}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'Reports',
#    'AreaProfile',
#    'CompareIndicators',
#    'Definitions',
#    'Inequalities',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': True,
#   'StartValueAxisFromZero': True,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  36: {'Id': 36,
#   'Name': 'Mental Health',
#   'Key': 'mental-health',
#   'GroupIds': [8000017],
#   'GroupMetadata': [{'Id': 8000017,
#     'Name': 'Mental health Dementia and Neurology',
#     'Sequence': 1,
#     'ProfileId': 36,
#     'DataAvailable': []}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'CompareIndicators',
#    'Definitions',
#    'Map',
#    'Download'],
#   'HasRecentTrends': False,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': False,
#   'HasOwnFrontPage': True},
#  45: {'Id': 45,
#   'Name': 'Sexual and Reproductive Health Profiles',
#   'Key': 'sexualhealth',
#   'GroupIds': [8000057, 8000035, 1938133286, 8000059, 8000036, 8000037],
#   'GroupMetadata': [{'Id': 8000057,
#     'Name': 'Key Indicators',
#     'Sequence': 1,
#     'ProfileId': 45,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 32},
#      {'AreaTypeId': 15, 'IndicatorCount': 32},
#      {'AreaTypeId': 221, 'IndicatorCount': 20},
#      {'AreaTypeId': 223, 'IndicatorCount': 2},
#      {'AreaTypeId': 401, 'IndicatorCount': 26},
#      {'AreaTypeId': 402, 'IndicatorCount': 32},
#      {'AreaTypeId': 501, 'IndicatorCount': 26},
#      {'AreaTypeId': 502, 'IndicatorCount': 32},
#      {'AreaTypeId': 15, 'IndicatorCount': 16}]},
#    {'Id': 8000035,
#     'Name': 'STI',
#     'Sequence': 2,
#     'ProfileId': 45,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 36},
#      {'AreaTypeId': 15, 'IndicatorCount': 36},
#      {'AreaTypeId': 221, 'IndicatorCount': 34},
#      {'AreaTypeId': 401, 'IndicatorCount': 34},
#      {'AreaTypeId': 402, 'IndicatorCount': 36},
#      {'AreaTypeId': 501, 'IndicatorCount': 34},
#      {'AreaTypeId': 502, 'IndicatorCount': 36},
#      {'AreaTypeId': 15, 'IndicatorCount': 17}]},
#    {'Id': 1938133286,
#     'Name': 'HIV',
#     'Sequence': 3,
#     'ProfileId': 45,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 36},
#      {'AreaTypeId': 15, 'IndicatorCount': 36},
#      {'AreaTypeId': 221, 'IndicatorCount': 30},
#      {'AreaTypeId': 401, 'IndicatorCount': 24},
#      {'AreaTypeId': 402, 'IndicatorCount': 34},
#      {'AreaTypeId': 501, 'IndicatorCount': 24},
#      {'AreaTypeId': 502, 'IndicatorCount': 34},
#      {'AreaTypeId': 15, 'IndicatorCount': 18}]},
#    {'Id': 8000059,
#     'Name': 'Reproductive Health',
#     'Sequence': 4,
#     'ProfileId': 45,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 44},
#      {'AreaTypeId': 15, 'IndicatorCount': 44},
#      {'AreaTypeId': 221, 'IndicatorCount': 30},
#      {'AreaTypeId': 223, 'IndicatorCount': 30},
#      {'AreaTypeId': 401, 'IndicatorCount': 32},
#      {'AreaTypeId': 402, 'IndicatorCount': 42},
#      {'AreaTypeId': 501, 'IndicatorCount': 32},
#      {'AreaTypeId': 502, 'IndicatorCount': 42},
#      {'AreaTypeId': 15, 'IndicatorCount': 22}]},
#    {'Id': 8000036,
#     'Name': 'Teenage Pregnancy',
#     'Sequence': 5,
#     'ProfileId': 45,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 12},
#      {'AreaTypeId': 401, 'IndicatorCount': 6},
#      {'AreaTypeId': 402, 'IndicatorCount': 12},
#      {'AreaTypeId': 501, 'IndicatorCount': 6},
#      {'AreaTypeId': 502, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 6}]},
#    {'Id': 8000037,
#     'Name': 'Wider Determinants of Health',
#     'Sequence': 6,
#     'ProfileId': 45,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 14},
#      {'AreaTypeId': 15, 'IndicatorCount': 14},
#      {'AreaTypeId': 401, 'IndicatorCount': 12},
#      {'AreaTypeId': 402, 'IndicatorCount': 14},
#      {'AreaTypeId': 501, 'IndicatorCount': 12},
#      {'AreaTypeId': 502, 'IndicatorCount': 14},
#      {'AreaTypeId': 15, 'IndicatorCount': 7}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'Reports',
#    'AreaProfile',
#    'CompareIndicators',
#    'Population',
#    'Definitions',
#    'Inequalities',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': True,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': True,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  46: {'Id': 46,
#   'Name': 'Atlas of Variation',
#   'Key': 'atlas-of-variation',
#   'GroupIds': [8000038],
#   'GroupMetadata': [{'Id': 8000038,
#     'Name': 'Atlas of variation',
#     'Sequence': 1,
#     'ProfileId': 46,
#     'DataAvailable': []}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'CompareIndicators',
#    'Definitions',
#    'Map',
#    'Download'],
#   'HasRecentTrends': True,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': False,
#   'HasOwnFrontPage': True},
#  50: {'Id': 50,
#   'Name': 'Adult mental health and wellbeing',
#   'Key': 'adult-mental-health-wellbeing',
#   'GroupIds': [1938133452,
#    1938133453,
#    1938133454,
#    1938133464,
#    1938133455,
#    1938133456],
#   'GroupMetadata': [{'Id': 1938133452,
#     'Name': 'Key indicators',
#     'Sequence': 1,
#     'ProfileId': 50,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 24},
#      {'AreaTypeId': 15, 'IndicatorCount': 46},
#      {'AreaTypeId': 221, 'IndicatorCount': 32},
#      {'AreaTypeId': 223, 'IndicatorCount': 14},
#      {'AreaTypeId': 502, 'IndicatorCount': 28},
#      {'AreaTypeId': 15, 'IndicatorCount': 20}]},
#    {'Id': 1938133453,
#     'Name': 'Identification of need',
#     'Sequence': 2,
#     'ProfileId': 50,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 20},
#      {'AreaTypeId': 15, 'IndicatorCount': 26},
#      {'AreaTypeId': 221, 'IndicatorCount': 14},
#      {'AreaTypeId': 223, 'IndicatorCount': 8},
#      {'AreaTypeId': 502, 'IndicatorCount': 24},
#      {'AreaTypeId': 15, 'IndicatorCount': 13}]},
#    {'Id': 1938133454,
#     'Name': 'Factors affecting mental health',
#     'Sequence': 3,
#     'ProfileId': 50,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 32},
#      {'AreaTypeId': 15, 'IndicatorCount': 54},
#      {'AreaTypeId': 221, 'IndicatorCount': 16},
#      {'AreaTypeId': 223, 'IndicatorCount': 8},
#      {'AreaTypeId': 502, 'IndicatorCount': 54},
#      {'AreaTypeId': 15, 'IndicatorCount': 29}]},
#    {'Id': 1938133464,
#     'Name': 'Wellbeing',
#     'Sequence': 4,
#     'ProfileId': 50,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 28},
#      {'AreaTypeId': 15, 'IndicatorCount': 40},
#      {'AreaTypeId': 221, 'IndicatorCount': 10},
#      {'AreaTypeId': 223, 'IndicatorCount': 4},
#      {'AreaTypeId': 502, 'IndicatorCount': 36},
#      {'AreaTypeId': 15, 'IndicatorCount': 19}]},
#    {'Id': 1938133455,
#     'Name': 'Services and access',
#     'Sequence': 5,
#     'ProfileId': 50,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 42},
#      {'AreaTypeId': 221, 'IndicatorCount': 26},
#      {'AreaTypeId': 223, 'IndicatorCount': 8},
#      {'AreaTypeId': 502, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 13}]},
#    {'Id': 1938133456,
#     'Name': 'Quality and outcomes',
#     'Sequence': 6,
#     'ProfileId': 50,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 38},
#      {'AreaTypeId': 15, 'IndicatorCount': 62},
#      {'AreaTypeId': 221, 'IndicatorCount': 28},
#      {'AreaTypeId': 223, 'IndicatorCount': 10},
#      {'AreaTypeId': 502, 'IndicatorCount': 38},
#      {'AreaTypeId': 15, 'IndicatorCount': 29}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'CompareIndicators',
#    'Definitions',
#    'Inequalities',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': True,
#   'StartValueAxisFromZero': True,
#   'IsChangeFromPreviousPeriodShown': True,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': True,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  55: {'Id': 55,
#   'Name': 'Liver Disease Profiles',
#   'Key': 'liver-disease',
#   'GroupIds': [8000063],
#   'GroupMetadata': [{'Id': 8000063,
#     'Name': 'Liver Disease',
#     'Sequence': 1,
#     'ProfileId': 55,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 84},
#      {'AreaTypeId': 15, 'IndicatorCount': 86},
#      {'AreaTypeId': 221, 'IndicatorCount': 22},
#      {'AreaTypeId': 223, 'IndicatorCount': 36},
#      {'AreaTypeId': 501, 'IndicatorCount': 42},
#      {'AreaTypeId': 502, 'IndicatorCount': 70},
#      {'AreaTypeId': 15, 'IndicatorCount': 19}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'CompareIndicators',
#    'Population',
#    'Definitions',
#    'Inequalities',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': True,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': True,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  58: {'Id': 58,
#   'Name': 'Learning Disability Profiles',
#   'Key': 'learning-disabilities',
#   'GroupIds': [1938132702],
#   'GroupMetadata': [{'Id': 1938132702,
#     'Name': 'Learning disability',
#     'Sequence': 1,
#     'ProfileId': 58,
#     'DataAvailable': [{'AreaTypeId': 15, 'IndicatorCount': 16},
#      {'AreaTypeId': 502, 'IndicatorCount': 16},
#      {'AreaTypeId': 15, 'IndicatorCount': 8}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'CompareIndicators',
#    'Definitions',
#    'Map',
#    'Download'],
#   'HasRecentTrends': True,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  65: {'Id': 65,
#   'Name': 'NHS Health Check',
#   'Key': 'nhs-health-check-detailed',
#   'GroupIds': [1938132726, 1938132768, 1938132770],
#   'GroupMetadata': [{'Id': 1938132726,
#     'Name': 'Health Check',
#     'Sequence': 1,
#     'ProfileId': 65,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 18},
#      {'AreaTypeId': 221, 'IndicatorCount': 18},
#      {'AreaTypeId': 223, 'IndicatorCount': 18},
#      {'AreaTypeId': 402, 'IndicatorCount': 18},
#      {'AreaTypeId': 502, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 9}]},
#    {'Id': 1938132768,
#     'Name': 'Risk factors',
#     'Sequence': 2,
#     'ProfileId': 65,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 8},
#      {'AreaTypeId': 221, 'IndicatorCount': 2},
#      {'AreaTypeId': 223, 'IndicatorCount': 2},
#      {'AreaTypeId': 402, 'IndicatorCount': 8},
#      {'AreaTypeId': 502, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 4}]},
#    {'Id': 1938132770,
#     'Name': 'Disease and death',
#     'Sequence': 3,
#     'ProfileId': 65,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 18},
#      {'AreaTypeId': 221, 'IndicatorCount': 4},
#      {'AreaTypeId': 223, 'IndicatorCount': 4},
#      {'AreaTypeId': 402, 'IndicatorCount': 18},
#      {'AreaTypeId': 502, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 8}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'CompareIndicators',
#    'Population',
#    'Definitions',
#    'Inequalities',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': True,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  76: {'Id': 76,
#   'Name': 'Musculoskeletal health profile',
#   'Key': 'msk',
#   'GroupIds': [1938133186,
#    1938133152,
#    1938133151,
#    1938133218,
#    1938132773,
#    1938133148,
#    1938133149,
#    1938133150],
#   'GroupMetadata': [{'Id': 1938133186,
#     'Name': 'Key Indicators',
#     'Sequence': 1,
#     'ProfileId': 76,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 22},
#      {'AreaTypeId': 15, 'IndicatorCount': 22},
#      {'AreaTypeId': 401, 'IndicatorCount': 22},
#      {'AreaTypeId': 402, 'IndicatorCount': 22},
#      {'AreaTypeId': 501, 'IndicatorCount': 22},
#      {'AreaTypeId': 502, 'IndicatorCount': 22},
#      {'AreaTypeId': 15, 'IndicatorCount': 11}]},
#    {'Id': 1938133152,
#     'Name': 'Risk factors',
#     'Sequence': 2,
#     'ProfileId': 76,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 10},
#      {'AreaTypeId': 401, 'IndicatorCount': 10},
#      {'AreaTypeId': 402, 'IndicatorCount': 10},
#      {'AreaTypeId': 501, 'IndicatorCount': 10},
#      {'AreaTypeId': 502, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 5}]},
#    {'Id': 1938133151,
#     'Name': 'Physical activity',
#     'Sequence': 3,
#     'ProfileId': 76,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 4},
#      {'AreaTypeId': 15, 'IndicatorCount': 4},
#      {'AreaTypeId': 401, 'IndicatorCount': 4},
#      {'AreaTypeId': 402, 'IndicatorCount': 4},
#      {'AreaTypeId': 501, 'IndicatorCount': 4},
#      {'AreaTypeId': 502, 'IndicatorCount': 4},
#      {'AreaTypeId': 15, 'IndicatorCount': 2}]},
#    {'Id': 1938133218,
#     'Name': 'MSK and comorbidity',
#     'Sequence': 4,
#     'ProfileId': 76,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 18},
#      {'AreaTypeId': 401, 'IndicatorCount': 18},
#      {'AreaTypeId': 402, 'IndicatorCount': 18},
#      {'AreaTypeId': 501, 'IndicatorCount': 18},
#      {'AreaTypeId': 502, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 9}]},
#    {'Id': 1938132773,
#     'Name': 'Back pain',
#     'Sequence': 5,
#     'ProfileId': 76,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 6},
#      {'AreaTypeId': 15, 'IndicatorCount': 6},
#      {'AreaTypeId': 501, 'IndicatorCount': 6},
#      {'AreaTypeId': 502, 'IndicatorCount': 6},
#      {'AreaTypeId': 15, 'IndicatorCount': 3}]},
#    {'Id': 1938133148,
#     'Name': 'Osteoarthritis',
#     'Sequence': 6,
#     'ProfileId': 76,
# ...
#     'ProfileId': 139,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 4},
#      {'AreaTypeId': 7, 'IndicatorCount': 6},
#      {'AreaTypeId': 15, 'IndicatorCount': 8},
#      {'AreaTypeId': 66, 'IndicatorCount': 8},
#      {'AreaTypeId': 221, 'IndicatorCount': 8},
#      {'AreaTypeId': 223, 'IndicatorCount': 4},
#      {'AreaTypeId': 502, 'IndicatorCount': 4},
#      {'AreaTypeId': 15, 'IndicatorCount': 4}]},
#    {'Id': 1938133136,
#     'Name': 'Care processes',
#     'Sequence': 4,
#     'ProfileId': 139,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 44},
#      {'AreaTypeId': 15, 'IndicatorCount': 46},
#      {'AreaTypeId': 66, 'IndicatorCount': 46},
#      {'AreaTypeId': 221, 'IndicatorCount': 46},
#      {'AreaTypeId': 15, 'IndicatorCount': 23}]},
#    {'Id': 1938133135,
#     'Name': 'Treatment targets',
#     'Sequence': 5,
#     'ProfileId': 139,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 16},
#      {'AreaTypeId': 15, 'IndicatorCount': 18},
#      {'AreaTypeId': 66, 'IndicatorCount': 18},
#      {'AreaTypeId': 221, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 9}]},
#    {'Id': 1938133158,
#     'Name': 'Structured education',
#     'Sequence': 6,
#     'ProfileId': 139,
#     'DataAvailable': [{'AreaTypeId': 15, 'IndicatorCount': 10},
#      {'AreaTypeId': 66, 'IndicatorCount': 10},
#      {'AreaTypeId': 221, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 5}]},
#    {'Id': 1938133137,
#     'Name': 'Complications and mortality',
#     'Sequence': 7,
#     'ProfileId': 139,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 14},
#      {'AreaTypeId': 66, 'IndicatorCount': 6},
#      {'AreaTypeId': 221, 'IndicatorCount': 12},
#      {'AreaTypeId': 223, 'IndicatorCount': 12},
#      {'AreaTypeId': 502, 'IndicatorCount': 8},
#      {'AreaTypeId': 15, 'IndicatorCount': 5}]},
#    {'Id': 1938133440,
#     'Name': 'QOF interventions',
#     'Sequence': 8,
#     'ProfileId': 139,
#     'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 18},
#      {'AreaTypeId': 66, 'IndicatorCount': 18},
#      {'AreaTypeId': 221, 'IndicatorCount': 18},
#      {'AreaTypeId': 223, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 9}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'CompareIndicators',
#    'Definitions',
#    'Inequalities',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': True,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': True,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  143: {'Id': 143,
#   'Name': 'Local health, public health data for small geographic areas',
#   'Key': 'local-health',
#   'GroupIds': [1938133180, 1938133183, 1938133184, 1938133185],
#   'GroupMetadata': [{'Id': 1938133180,
#     'Name': 'Our community',
#     'Sequence': 1,
#     'ProfileId': 143,
#     'DataAvailable': [{'AreaTypeId': 3, 'IndicatorCount': 22},
#      {'AreaTypeId': 15, 'IndicatorCount': 22},
#      {'AreaTypeId': 501, 'IndicatorCount': 22},
#      {'AreaTypeId': 502, 'IndicatorCount': 22},
#      {'AreaTypeId': 15, 'IndicatorCount': 11}]},
#    {'Id': 1938133183,
#     'Name': 'Behavioural risk factors and child health',
#     'Sequence': 2,
#     'ProfileId': 143,
#     'DataAvailable': [{'AreaTypeId': 3, 'IndicatorCount': 20},
#      {'AreaTypeId': 15, 'IndicatorCount': 20},
#      {'AreaTypeId': 501, 'IndicatorCount': 20},
#      {'AreaTypeId': 502, 'IndicatorCount': 20},
#      {'AreaTypeId': 15, 'IndicatorCount': 10}]},
#    {'Id': 1938133184,
#     'Name': 'Disease and poor health',
#     'Sequence': 3,
#     'ProfileId': 143,
#     'DataAvailable': [{'AreaTypeId': 3, 'IndicatorCount': 18},
#      {'AreaTypeId': 15, 'IndicatorCount': 28},
#      {'AreaTypeId': 501, 'IndicatorCount': 28},
#      {'AreaTypeId': 502, 'IndicatorCount': 28},
#      {'AreaTypeId': 15, 'IndicatorCount': 14}]},
#    {'Id': 1938133185,
#     'Name': 'Life expectancy and causes of death',
#     'Sequence': 4,
#     'ProfileId': 143,
#     'DataAvailable': [{'AreaTypeId': 3, 'IndicatorCount': 24},
#      {'AreaTypeId': 15, 'IndicatorCount': 24},
#      {'AreaTypeId': 501, 'IndicatorCount': 24},
#      {'AreaTypeId': 502, 'IndicatorCount': 24},
#      {'AreaTypeId': 15, 'IndicatorCount': 11}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'CompareIndicators',
#    'Definitions',
#    'Map',
#    'Download'],
#   'HasRecentTrends': False,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 0,
#   'IgnoredSpineChartAreas': None,
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  147: {'Id': 147,
#   'Name': 'Cardiovascular Disease, Diabetes and Kidney Disease',
#   'Key': 'cardiovascular-disease-diabetes-kidney-disease',
#   'GroupIds': [1938133264],
#   'GroupMetadata': [{'Id': 1938133264,
#     'Name': 'N/A',
#     'Sequence': 1,
#     'ProfileId': 147,
#     'DataAvailable': []}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'Definitions',
#    'Download'],
#   'HasRecentTrends': False,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': -1,
#   'IgnoredSpineChartAreas': None,
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': False,
#   'HasOwnFrontPage': False},
#  148: {'Id': 148,
#   'Name': 'Diabetes Footcare',
#   'Key': 'diabetes-footcare',
#   'GroupIds': [1938133265],
#   'GroupMetadata': [{'Id': 1938133265,
#     'Name': 'N/A',
#     'Sequence': 1,
#     'ProfileId': 148,
#     'DataAvailable': []}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'Definitions',
#    'Download'],
#   'HasRecentTrends': False,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': False,
#   'HasOwnFrontPage': True},
#  154: {'Id': 154,
#   'Name': 'Inequality Tools',
#   'Key': 'inequality-tools',
#   'GroupIds': [1938133282],
#   'GroupMetadata': [{'Id': 1938133282,
#     'Name': 'Segment Tool',
#     'Sequence': 1,
#     'ProfileId': 154,
#     'DataAvailable': []}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'Definitions',
#    'Map',
#    'Download'],
#   'HasRecentTrends': False,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': False,
#   'HasOwnFrontPage': True},
#  155: {'Id': 155,
#   'Name': 'SPOT - Live',
#   'Key': 'spot',
#   'GroupIds': [1938133283, 1938133284, 1938133285, 1938133299],
#   'GroupMetadata': [{'Id': 1938133283,
#     'Name': 'Spend',
#     'Sequence': 1,
#     'ProfileId': 155,
#     'DataAvailable': [{'AreaTypeId': 15, 'IndicatorCount': 300},
#      {'AreaTypeId': 202, 'IndicatorCount': 300},
#      {'AreaTypeId': 15, 'IndicatorCount': 150}]},
#    {'Id': 1938133284,
#     'Name': 'Outcomes - SPOT only',
#     'Sequence': 2,
#     'ProfileId': 155,
#     'DataAvailable': [{'AreaTypeId': 15, 'IndicatorCount': 236},
#      {'AreaTypeId': 202, 'IndicatorCount': 216},
#      {'AreaTypeId': 15, 'IndicatorCount': 115}]},
#    {'Id': 1938133285,
#     'Name': 'Outcomes - PHOLIO 1',
#     'Sequence': 3,
#     'ProfileId': 155,
#     'DataAvailable': [{'AreaTypeId': 15, 'IndicatorCount': 210},
#      {'AreaTypeId': 202, 'IndicatorCount': 212},
#      {'AreaTypeId': 15, 'IndicatorCount': 103}]},
#    {'Id': 1938133299,
#     'Name': 'Outcomes - PHOLIO 2',
#     'Sequence': 4,
#     'ProfileId': 155,
#     'DataAvailable': [{'AreaTypeId': 15, 'IndicatorCount': 194},
#      {'AreaTypeId': 202, 'IndicatorCount': 194},
#      {'AreaTypeId': 15, 'IndicatorCount': 90}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'CompareIndicators',
#    'Definitions',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': False,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  156: {'Id': 156,
#   'Name': 'Development Profile for Testing fingertipsR',
#   'Key': 'development-profile-for-testing-fingertipsr',
#   'GroupIds': [1938133293, 1938133294, 1938133301],
#   'GroupMetadata': [{'Id': 1938133293,
#     'Name': 'Domain 1',
#     'Sequence': 1,
#     'ProfileId': 156,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 2},
#      {'AreaTypeId': 15, 'IndicatorCount': 2},
#      {'AreaTypeId': 15, 'IndicatorCount': 1}]},
#    {'Id': 1938133294,
#     'Name': 'Domain 2',
#     'Sequence': 2,
#     'ProfileId': 156,
#     'DataAvailable': [{'AreaTypeId': 15, 'IndicatorCount': 2},
#      {'AreaTypeId': 15, 'IndicatorCount': 1}]},
#    {'Id': 1938133301,
#     'Name': 'Domain 3',
#     'Sequence': 3,
#     'ProfileId': 156,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 4},
#      {'AreaTypeId': 15, 'IndicatorCount': 4},
#      {'AreaTypeId': 15, 'IndicatorCount': 1}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'Definitions',
#    'Download'],
#   'HasRecentTrends': True,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': False},
#  159: {'Id': 159,
#   'Name': "Perinatal, children and young people's mental health",
#   'Key': 'perinatal-cyp-mental-health',
#   'GroupIds': [1938133457, 1938133458, 1938133459, 1938133460, 1938133461],
#   'GroupMetadata': [{'Id': 1938133457,
#     'Name': 'Key indicators',
#     'Sequence': 1,
#     'ProfileId': 159,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 24},
#      {'AreaTypeId': 15, 'IndicatorCount': 24},
#      {'AreaTypeId': 221, 'IndicatorCount': 18},
#      {'AreaTypeId': 223, 'IndicatorCount': 22},
#      {'AreaTypeId': 502, 'IndicatorCount': 22},
#      {'AreaTypeId': 15, 'IndicatorCount': 13}]},
#    {'Id': 1938133458,
#     'Name': 'Identification of need',
#     'Sequence': 2,
#     'ProfileId': 159,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 16},
#      {'AreaTypeId': 221, 'IndicatorCount': 6},
#      {'AreaTypeId': 223, 'IndicatorCount': 10},
#      {'AreaTypeId': 502, 'IndicatorCount': 10},
#      {'AreaTypeId': 15, 'IndicatorCount': 9}]},
#    {'Id': 1938133459,
#     'Name': 'Factors affecting perinatal mental health',
#     'Sequence': 3,
#     'ProfileId': 159,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 42},
#      {'AreaTypeId': 15, 'IndicatorCount': 56},
#      {'AreaTypeId': 221, 'IndicatorCount': 36},
#      {'AreaTypeId': 223, 'IndicatorCount': 32},
#      {'AreaTypeId': 502, 'IndicatorCount': 48},
#      {'AreaTypeId': 15, 'IndicatorCount': 28}]},
#    {'Id': 1938133460,
#     'Name': "Factors affecting children and young people's mental health",
#     'Sequence': 4,
#     'ProfileId': 159,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 50},
#      {'AreaTypeId': 15, 'IndicatorCount': 84},
#      {'AreaTypeId': 221, 'IndicatorCount': 20},
#      {'AreaTypeId': 223, 'IndicatorCount': 18},
#      {'AreaTypeId': 502, 'IndicatorCount': 82},
#      {'AreaTypeId': 15, 'IndicatorCount': 42}]},
#    {'Id': 1938133461,
#     'Name': 'Services and outcomes',
#     'Sequence': 5,
#     'ProfileId': 159,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 24},
#      {'AreaTypeId': 15, 'IndicatorCount': 26},
#      {'AreaTypeId': 221, 'IndicatorCount': 18},
#      {'AreaTypeId': 223, 'IndicatorCount': 16},
#      {'AreaTypeId': 502, 'IndicatorCount': 24},
#      {'AreaTypeId': 15, 'IndicatorCount': 13}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'CompareIndicators',
#    'Definitions',
#    'Inequalities',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': True,
#   'StartValueAxisFromZero': True,
#   'IsChangeFromPreviousPeriodShown': True,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': True,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True},
#  161: {'Id': 161,
#   'Name': 'Cardiovascular Disease Prevention',
#   'Key': 'cardiovascular-disease-prevention',
#   'GroupIds': [1938133344],
#   'GroupMetadata': [{'Id': 1938133344,
#     'Name': 'N/A',
#     'Sequence': 1,
#     'ProfileId': 161,
#     'DataAvailable': []}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'Definitions',
#    'Download'],
#   'HasRecentTrends': False,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': None,
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': False,
#   'HasOwnFrontPage': True},
#  165: {'Id': 165,
#   'Name': 'Vision',
#   'Key': 'vision',
#   'GroupIds': [1938133375, 1938133392, 1938133391, 1938133390, 1938133420],
#   'GroupMetadata': [{'Id': 1938133375,
#     'Name': 'Outpatients',
#     'Sequence': 1,
#     'ProfileId': 165,
#     'DataAvailable': [{'AreaTypeId': 15, 'IndicatorCount': 4},
#      {'AreaTypeId': 66, 'IndicatorCount': 4},
#      {'AreaTypeId': 221, 'IndicatorCount': 4},
#      {'AreaTypeId': 223, 'IndicatorCount': 4},
#      {'AreaTypeId': 15, 'IndicatorCount': 2}]},
#    {'Id': 1938133392,
#     'Name': 'Procedures',
#     'Sequence': 2,
#     'ProfileId': 165,
#     'DataAvailable': [{'AreaTypeId': 15, 'IndicatorCount': 6},
#      {'AreaTypeId': 66, 'IndicatorCount': 6},
#      {'AreaTypeId': 221, 'IndicatorCount': 6},
#      {'AreaTypeId': 223, 'IndicatorCount': 6},
#      {'AreaTypeId': 15, 'IndicatorCount': 3}]},
#    {'Id': 1938133391,
#     'Name': 'Sight loss outcomes',
#     'Sequence': 3,
#     'ProfileId': 165,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 12},
#      {'AreaTypeId': 221, 'IndicatorCount': 4},
#      {'AreaTypeId': 223, 'IndicatorCount': 4},
#      {'AreaTypeId': 502, 'IndicatorCount': 12},
#      {'AreaTypeId': 15, 'IndicatorCount': 6}]},
#    {'Id': 1938133390,
#     'Name': 'Risk factors',
#     'Sequence': 4,
#     'ProfileId': 165,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 16},
#      {'AreaTypeId': 15, 'IndicatorCount': 30},
#      {'AreaTypeId': 66, 'IndicatorCount': 14},
#      {'AreaTypeId': 221, 'IndicatorCount': 12},
#      {'AreaTypeId': 223, 'IndicatorCount': 6},
#      {'AreaTypeId': 402, 'IndicatorCount': 6},
#      {'AreaTypeId': 501, 'IndicatorCount': 16},
#      {'AreaTypeId': 502, 'IndicatorCount': 20},
#      {'AreaTypeId': 15, 'IndicatorCount': 14}]},
#    {'Id': 1938133420,
#     'Name': 'All indicators',
#     'Sequence': 5,
#     'ProfileId': 165,
#     'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 26},
#      {'AreaTypeId': 15, 'IndicatorCount': 50},
#      {'AreaTypeId': 66, 'IndicatorCount': 20},
#      {'AreaTypeId': 221, 'IndicatorCount': 22},
#      {'AreaTypeId': 223, 'IndicatorCount': 18},
#      {'AreaTypeId': 402, 'IndicatorCount': 12},
#      {'AreaTypeId': 501, 'IndicatorCount': 16},
#      {'AreaTypeId': 502, 'IndicatorCount': 32},
#      {'AreaTypeId': 15, 'IndicatorCount': 24}]}],
#   'Visualisations': ['Overview',
#    'CompareAreas',
#    'Trends',
#    'AreaProfile',
#    'CompareIndicators',
#    'Definitions',
#    'Inequalities',
#    'BoxPlots',
#    'Map',
#    'Download'],
#   'HasRecentTrends': False,
#   'StartValueAxisFromZero': False,
#   'IsChangeFromPreviousPeriodShown': False,
#   'DefaultAreaTypeId': 15,
#   'DefaultTabId': 1,
#   'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#   'OpenInequalitiesOnAreaData': False,
#   'HasAnyData': True,
#   'HasOwnFrontPage': True}}

# %%
import pandas as pd

profiles_df = pd.DataFrame([
    {
        "ProfileId": profile["Id"],
        "ProfileName": profile["Name"],
        "ProfileKey": profile["Key"]
    }
    for profile in available_profiles.values()
])

profiles_df.sort_values("ProfileName").reset_index(drop=True)
# Out:
#     ProfileId                                        ProfileName  \
# 0         101       AMR local indicators - produced by the UKHSA
# 1          50                  Adult mental health and wellbeing
# 2          87                                    Alcohol Profile
# 3          46                                 Atlas of Variation
# 4          92                                    Cancer Services
# 5         135                             Cardiovascular Disease
# 6         161                  Cardiovascular Disease Prevention
# 7         147  Cardiovascular Disease, Diabetes and Kidney Di...
# 8         105                          Child and Maternal Health
# 9          84                                   Dementia Profile
# 10        156        Development Profile for Testing fingertipsR
# 11        139                                           Diabetes
# 12        148                                  Diabetes Footcare
# 13        137                                Fingertips guidance
# 14         30                                  Health Protection
# 15        154                                   Inequality Tools
# 16         58                       Learning Disability Profiles
# 17         55                             Liver Disease Profiles
# 18         26                    Local Authority Health Profiles
# 19        143  Local health, public health data for small geo...
# 20         36                                      Mental Health
# 21        125                                  Mortality Profile
# 22         76                     Musculoskeletal health profile
# 23         65                                   NHS Health Check
# 24         20                 National General Practice Profiles
# 25         21  National General Practice Profiles (supporting...
# 26         32           Obesity, physical activity and nutrition
# 27         95           Palliative and End of Life Care Profiles
# 28        159  Perinatal, children and young people's mental ...
# 29        132                                        Populations
# 30         19                   Public Health Outcomes Framework
# 31         29                                Respiratory disease
# 32        155                                        SPOT - Live
# 33         45            Sexual and Reproductive Health Profiles
# 34         18                                    Smoking Profile
# 35         91                                 Suicide Prevention
# 36         86                  TB Strategy Monitoring Indicators
# 37        165                                             Vision
# 38        130                       Wider Determinants of Health
#
#                                         ProfileKey
# 0                             amr-local-indicators
# 1                    adult-mental-health-wellbeing
# 2                           local-alcohol-profiles
# 3                               atlas-of-variation
# 4                                   cancerservices
# 5                                   cardiovascular
# 6                cardiovascular-disease-prevention
# 7   cardiovascular-disease-diabetes-kidney-disease
# 8                            child-health-profiles
# 9                                         dementia
# 10     development-profile-for-testing-fingertipsr
# 11                                     diabetes-ft
# 12                               diabetes-footcare
# 13                                        guidance
# 14                               health-protection
# 15                                inequality-tools
# 16                           learning-disabilities
# 17                                   liver-disease
# 18                                 health-profiles
# 19                                    local-health
# 20                                   mental-health
# 21                               mortality-profile
# 22                                             msk
# 23                       nhs-health-check-detailed
# 24                                general-practice
# 25         practice-profiles-supporting-indicators
# 26             obesity-physical-activity-nutrition
# 27                                     end-of-life
# 28                     perinatal-cyp-mental-health
# 29                                     populations
# 30                public-health-outcomes-framework
# 31                             respiratory-disease
# 32                                            spot
# 33                                    sexualhealth
# 34                                 tobacco-control
# 35                              suicide-prevention
# 36                                   tb-monitoring
# 37                                          vision
# 38                              wider-determinants

# %%
help(ftp.get_all_profiles)
# Out:
# Help on function get_all_profiles in module fingertips_py.metadata:
#
# get_all_profiles(is_test=False)
#     Returns all profiles.
#
#     :param is_test: Used for testing. Returns a tuple of expected return and the URL called to retrieve the data
#     :return: A dictionary of all profiles in Fingertips including information on domains and sequencing

# %% [markdown]
# Public Health Outcomes Framework selected because it contains indicators related to healthcare activity, hospital usage, and outcomes.

# %%
profiles_df[profiles_df["ProfileName"].str.contains("outcomes", case=False)]
# Out:
#    ProfileId                       ProfileName  \
# 1         19  Public Health Outcomes Framework
#
#                          ProfileKey
# 1  public-health-outcomes-framework

# %%
phof_profile = ftp.get_profile_by_name("public health outcomes framework")
phof_profile
# Out:
# {'Id': 19,
#  'Name': 'Public Health Outcomes Framework',
#  'Key': 'public-health-outcomes-framework',
#  'GroupIds': [1000049, 1000041, 1000042, 1000043, 1000044, 1938132983],
#  'GroupMetadata': [{'Id': 1000049,
#    'Name': 'A. Overarching indicators',
#    'Sequence': 1,
#    'ProfileId': 19,
#    'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 40},
#     {'AreaTypeId': 15, 'IndicatorCount': 44},
#     {'AreaTypeId': 221, 'IndicatorCount': 8},
#     {'AreaTypeId': 223, 'IndicatorCount': 8},
#     {'AreaTypeId': 301, 'IndicatorCount': 24},
#     {'AreaTypeId': 302, 'IndicatorCount': 38},
#     {'AreaTypeId': 501, 'IndicatorCount': 24},
#     {'AreaTypeId': 502, 'IndicatorCount': 44},
#     {'AreaTypeId': 15, 'IndicatorCount': 10}]},
#   {'Id': 1000041,
#    'Name': 'B. Wider determinants of health',
#    'Sequence': 2,
#    'ProfileId': 19,
#    'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 72},
#     {'AreaTypeId': 15, 'IndicatorCount': 72},
#     {'AreaTypeId': 221, 'IndicatorCount': 32},
#     {'AreaTypeId': 223, 'IndicatorCount': 32},
#     {'AreaTypeId': 301, 'IndicatorCount': 36},
#     {'AreaTypeId': 302, 'IndicatorCount': 72},
#     {'AreaTypeId': 501, 'IndicatorCount': 36},
#     {'AreaTypeId': 502, 'IndicatorCount': 72},
#     {'AreaTypeId': 15, 'IndicatorCount': 36}]},
#   {'Id': 1000042,
#    'Name': 'C. Health improvement',
#    'Sequence': 3,
#    'ProfileId': 19,
#    'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 130},
#     {'AreaTypeId': 15, 'IndicatorCount': 130},
#     {'AreaTypeId': 221, 'IndicatorCount': 62},
#     {'AreaTypeId': 223, 'IndicatorCount': 50},
#     {'AreaTypeId': 301, 'IndicatorCount': 72},
#     {'AreaTypeId': 302, 'IndicatorCount': 110},
#     {'AreaTypeId': 501, 'IndicatorCount': 72},
#     {'AreaTypeId': 502, 'IndicatorCount': 110},
#     {'AreaTypeId': 15, 'IndicatorCount': 63}]},
#   {'Id': 1000043,
#    'Name': 'D. Health protection',
#    'Sequence': 4,
#    'ProfileId': 19,
#    'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 72},
#     {'AreaTypeId': 15, 'IndicatorCount': 72},
#     {'AreaTypeId': 221, 'IndicatorCount': 64},
#     {'AreaTypeId': 223, 'IndicatorCount': 26},
#     {'AreaTypeId': 301, 'IndicatorCount': 18},
#     {'AreaTypeId': 302, 'IndicatorCount': 72},
#     {'AreaTypeId': 501, 'IndicatorCount': 18},
#     {'AreaTypeId': 502, 'IndicatorCount': 72},
#     {'AreaTypeId': 15, 'IndicatorCount': 33}]},
#   {'Id': 1000044,
#    'Name': 'E. Healthcare and premature mortality',
#    'Sequence': 5,
#    'ProfileId': 19,
#    'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 70},
#     {'AreaTypeId': 15, 'IndicatorCount': 72},
#     {'AreaTypeId': 221, 'IndicatorCount': 60},
#     {'AreaTypeId': 223, 'IndicatorCount': 60},
#     {'AreaTypeId': 301, 'IndicatorCount': 50},
#     {'AreaTypeId': 302, 'IndicatorCount': 62},
#     {'AreaTypeId': 501, 'IndicatorCount': 50},
#     {'AreaTypeId': 502, 'IndicatorCount': 62},
#     {'AreaTypeId': 15, 'IndicatorCount': 26}]},
#   {'Id': 1938132983,
#    'Name': 'Supporting information',
#    'Sequence': 6,
#    'ProfileId': 19,
#    'DataAvailable': [{'AreaTypeId': 6, 'IndicatorCount': 10},
#     {'AreaTypeId': 15, 'IndicatorCount': 10},
#     {'AreaTypeId': 221, 'IndicatorCount': 6},
#     {'AreaTypeId': 223, 'IndicatorCount': 6},
#     {'AreaTypeId': 301, 'IndicatorCount': 10},
#     {'AreaTypeId': 302, 'IndicatorCount': 10},
#     {'AreaTypeId': 501, 'IndicatorCount': 10},
#     {'AreaTypeId': 502, 'IndicatorCount': 10},
#     {'AreaTypeId': 15, 'IndicatorCount': 5}]}],
#  'Visualisations': ['Overview',
#   'CompareAreas',
#   'Trends',
#   'Reports',
#   'AreaProfile',
#   'CompareIndicators',
#   'Population',
#   'Definitions',
#   'Inequalities',
#   'BoxPlots',
#   'Map',
#   'Download'],
#  'HasRecentTrends': True,
#  'StartValueAxisFromZero': True,
#  'IsChangeFromPreviousPeriodShown': True,
#  'DefaultAreaTypeId': 502,
#  'DefaultTabId': 3,
#  'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#  'OpenInequalitiesOnAreaData': False,
#  'HasAnyData': True,
#  'HasOwnFrontPage': True}

# %%
# Pull all indicator metadata for the PHOF profile
phof_indicators_df = ftp.get_metadata_for_profile_as_dataframe(phof_profile["Id"])

# Preview structure
phof_indicators_df.head()
# Out:
#    Indicator ID                                        Indicator  \
# 0         90362          A01a - Healthy life expectancy at birth
# 1         90366                  A01b - Life expectancy at birth
# 2         91102                     A01b - Life expectancy at 65
# 3         93562  A01c - Disability free life expectancy at birth
# 4         92901    A02a - Inequality in life expectancy at birth
#
#   Indicator number                                          Rationale  \
# 0             A01a  This indicator is an extremely important summa...
# 1             A01b  This indicator gives context to healthy life e...
# 2             A01b  This indicator gives context to healthy life e...
# 3             A01c  This indicator will provide more information o...
# 4             A02a  This is a key high level health inequalities o...
#
#   Specific rationale                                         Definition  \
# 0                NaN  A measure of the average number of years a per...
# 1                NaN  The average number of years a person would exp...
# 2                NaN  The average number of years a person would exp...
# 3                NaN  A measure of the average number of years a per...
# 4                NaN  This indicator measures inequalities in life e...
#
#                                          Data source  \
# 0                     Office for National Statistics
# 1                     Office for National Statistics
# 2                     Office for National Statistics
# 3                     Office for National Statistics
# 4  OHID, based on Ministry of Housing, Communitie...
#
#                                     Indicator source  \
# 0  <span style="line-height: 115%; mso-ascii-them...
# 1  https://www.ons.gov.uk/peoplepopulationandcomm...
# 2  https://www.ons.gov.uk/peoplepopulationandcomm...
# 3  <p class="MsoNormal">Office for National Stati...
# 4                                                NaN
#
#                              Definition of numerator  \
# 0  Number of deaths registered in the respective ...
# 1  Number of deaths registered in the respective ...
# 2  Number of deaths registered in the respective ...
# 3                                                NaN
# 4                                                NaN
#
#                                  Source of numerator  ...  \
# 0  Office for National Statistics (ONS), Annual b...  ...
# 1  Office for National Statistics (ONS), Annual m...  ...
# 2  Office for National Statistics (ONS), Annual m...  ...
# 3  Office for National Statistics (ONS), Annual b...  ...
# 4  Office for National Statistics (ONS), Annual m...  ...
#
#                                          Data re-use  \
# 0  You may use and re use Crown copyright informa...
# 1  You may use and re use Crown copyright informa...
# 2  You may use and re use Crown copyright informa...
# 3  You may use and re use Crown copyright informa...
# 4  You may use and re use Crown copyright informa...
#
#                                                Links Indicator Content  \
# 0  Guides to the methods used in calculation of t...               NaN
# 1  Life expectancy at birth: methodological optio...               NaN
# 2  Life expectancy: methodological options for sm...               NaN
# 3  <p class="MsoNormal">Guides to the methods use...               NaN
# 4  <p class="MsoNormal">Guides to the methods use...               NaN
#
#                               Simple Name  \
# 0        Healthy life expectancy at birth
# 1                Life expectancy at birth
# 2                                     NaN
# 3                                     NaN
# 4  Inequality in life expectancy at birth
#
#                                    Simple Definition   Unit  \
# 0  The average number of years a person would exp...  Years
# 1  The average number of years a person would exp...  Years
# 2                                                NaN  Years
# 3                                                NaN  Years
# 4  The difference between the most and least depr...  Years
#
#                   Value type Year type            Polarity Date updated
# 0            Life expectancy  Calendar  RAG - High is good   21/07/2025
# 1            Life expectancy  Calendar  RAG - High is good   23/04/2025
# 2            Life expectancy  Calendar  RAG - High is good   23/04/2025
# 3            Life expectancy  Calendar  RAG - High is good   05/04/2022
# 4  Slope Index of Inequality  Calendar   RAG - Low is good   23/04/2025
#
# [5 rows x 32 columns]

# %%
phof_indicators_df.columns
# Out:
# Index(['Indicator ID', 'Indicator', 'Indicator number', 'Rationale',
#        'Specific rationale', 'Definition', 'Data source', 'Indicator source',
#        'Definition of numerator', 'Source of numerator',
#        'Definition of denominator', 'Source of denominator', 'Methodology',
#        'Standard population/values', 'Frequency',
#        'Confidence interval details', 'Disclosure control', 'Rounding',
#        'Caveats', 'Notes', 'Impact of COVID-19', 'Copyright', 'Data re-use',
#        'Links', 'Indicator Content', 'Simple Name', 'Simple Definition',
#        'Unit', 'Value type', 'Year type', 'Polarity', 'Date updated'],
#       dtype='object')

# %%
admissions_candidates_df = phof_indicators_df[
    phof_indicators_df["Indicator"].str.contains(
        "admission|emergency|hospital|avoidable|preventable",
        case=False,
        na=False
    )
]

admissions_candidates_df[["Indicator ID", "Indicator"]].sort_values("Indicator").head(25)
# Out:
#      Indicator ID                                          Indicator
# 20          11201  B12a - Violent crime - hospital admissions for...
# 58          90284  C11a - Hospital admissions caused by unintenti...
# 60          90832  C11a - Hospital admissions caused by unintenti...
# 61          90285  C11b - Hospital admissions caused by unintenti...
# 63          21001  C14b - Emergency Hospital Admissions for Inten...
# 78          93764  C21 - Admission episodes for alcohol-related c...
# 84          22401  C29 - Emergency hospital admissions due to fal...
# 87          22402  C29 - Emergency hospital admissions due to fal...
# 88          22403  C29 - Emergency hospital admissions due to fal...
# 144         93721  E03 - Under 75 mortality rate from causes cons...
# 146         93722  E04b - Under 75 mortality rate from cardiovasc...
# 148         93723  E05b - Under 75 mortality rate from cancer con...
# 150         93720  E06b - Under 75 mortality rate from liver dise...
# 152         93724  E07b - Under 75 mortality rate from respirator...
# 156         41101  E11 - Emergency readmissions within 30 days of...
# 160         41201  E12a - Preventable sight loss: age related mac...
# 162         41202            E12b - Preventable sight loss: glaucoma
# 164         41203  E12c - Preventable sight loss: diabetic eye di...
# 166         41204  E12d - Preventable sight loss: sight loss cert...

# %% [markdown]
# This indicator helps explain healthcare cost differences by showing who uses emergency care more frequently.

# %%
# Set chosen indicator
ADMISSIONS_INDICATOR_ID = 21001

# Pull data using API
admissions_raw_df = ftp.get_data_for_indicator_at_all_available_geographies(ADMISSIONS_INDICATOR_ID)

# Preview data
admissions_raw_df.head()
# Out:
# C:\Users\selen\AppData\Local\Programs\Python\Python314\Lib\site-packages\fingertips_py\retrieve_data.py:164: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, df_temp])
#   Indicator ID                                     Indicator Name Parent Code  \
# 0        21001  Emergency Hospital Admissions for Intentional ...         NaN
# 1        21001  Emergency Hospital Admissions for Intentional ...         NaN
# 2        21001  Emergency Hospital Admissions for Intentional ...         NaN
# 3        21001  Emergency Hospital Admissions for Intentional ...   E92000001
# 4        21001  Emergency Hospital Admissions for Intentional ...   E92000001
#
#   Parent Name  Area Code Area Name Area Type      Sex       Age Category Type  \
# 0         NaN  E92000001   England   England     Male  All ages           NaN
# 1         NaN  E92000001   England   England   Female  All ages           NaN
# 2         NaN  E92000001   England   England  Persons  All ages           NaN
# 3     England  E92000001   England   England     Male  All ages           NaN
# 4     England  E92000001   England   England   Female  All ages           NaN
#
#    ...     Count Denominator  Value note  Recent Trend  \
# 0  ...   43319.0  25877244.0         NaN           NaN
# 1  ...   65372.0  26765208.0         NaN           NaN
# 2  ...  108694.0  52642452.0         NaN           NaN
# 3  ...   43319.0  25877244.0         NaN           NaN
# 4  ...   65372.0  26765208.0         NaN           NaN
#
#    Compared to England value or percentiles  Compared to percentiles  \
# 0                              Not compared             Not compared
# 1                              Not compared             Not compared
# 2                              Not compared             Not compared
# 3                                   Similar             Not compared
# 4                                   Similar             Not compared
#
#    Time period Sortable  New data  Compared to goal Time period range
# 0              20100000       NaN               NaN                1y
# 1              20100000       NaN               NaN                1y
# 2              20100000       NaN               NaN                1y
# 3              20100000       NaN               NaN                1y
# 4              20100000       NaN               NaN                1y
#
# [5 rows x 27 columns]

# %% [markdown]
# Clean Data Set

# %%
admissions_raw_df[['Time period', 'Time period Sortable', 'Time period range']].head(10)
# Out:
#   Time period Time period Sortable Time period range
# 0     2010/11             20100000                1y
# 1     2010/11             20100000                1y
# 2     2010/11             20100000                1y
# 3     2010/11             20100000                1y
# 4     2010/11             20100000                1y
# 5     2010/11             20100000                1y
# 6     2010/11             20100000                1y
# 7     2010/11             20100000                1y
# 8     2010/11             20100000                1y
# 9     2010/11             20100000                1y

# %%
# Select analysis columns
admissions_clean_df = admissions_raw_df[
    ['Time period Sortable', 'Sex', 'Area Name', 'Value']
].copy()

# Rename columns
admissions_clean_df.columns = ['Year', 'Sex', 'Area', 'Value']

# Convert sortable year into numeric year
admissions_clean_df['Year'] = admissions_clean_df['Year'].astype(int) // 10000

# Ensure Value is numeric
admissions_clean_df['Value'] = pd.to_numeric(admissions_clean_df['Value'], errors='coerce')

# Filter to male vs female only
admissions_clean_df = admissions_clean_df[admissions_clean_df['Sex'].isin(['Male', 'Female'])]

# Preview clean data
admissions_clean_df.head()
# Out:
#    Year     Sex        Area       Value
# 0  2010    Male     England  160.411961
# 1  2010  Female     England  235.857736
# 3  2010    Male     England  160.411961
# 4  2010  Female     England  235.857736
# 6  2010    Male  Hartlepool  352.142738

# %% [markdown]
# Fingertips displays time as a formatted label (e.g. "2010/11") and a numeric sortable value. We used the sortable time field to safely extract numerical years for trend analysis.

# %%
admissions_clean_df['Year'].unique()[:6]
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015])

# %%
# Remove duplicate England entries
admissions_final_df = admissions_clean_df.drop_duplicates(
    subset=['Year', 'Sex', 'Area']
)

admissions_final_df.head()
# Out:
#    Year     Sex                  Area       Value
# 0  2010    Male               England  160.411961
# 1  2010  Female               England  235.857736
# 6  2010    Male            Hartlepool  352.142738
# 7  2010    Male         Middlesbrough  458.955084
# 8  2010    Male  Redcar and Cleveland  328.612959

# %% [markdown]
# Visusals

# %%
import matplotlib.pyplot as plt

latest_year = admissions_final_df['Year'].max()
england_latest = admissions_final_df[
    (admissions_final_df['Area'] == 'England') &
    (admissions_final_df['Year'] == latest_year)
]

grouped = england_latest.groupby('Sex', as_index=False)['Value'].mean()

ax = grouped.plot(kind='bar', x='Sex', y='Value', legend=False)
ax.set_title(f"Emergency Hospital Admission Rate by Sex in England ({latest_year})")
ax.set_ylabel("Admissions per 100,000")
plt.tight_layout()
plt.show()

# %% [markdown]
# Bar plot comparing emergency hospital admission rates by sexup to the most recent year,
#
# Females consistently show higher emergency admission rates
#
# This implies:
#
# *Greater demand for urgent care
#
# *Greater short-term cost burden
#
# *Higher pressure on NHS services from female patients in this category
#
#
#
# Females consistently record higher emergency admission rates than males, suggesting greater usage of urgent healthcare services.

# %%
england_trend = admissions_final_df[
    admissions_final_df['Area'] == 'England'
].pivot_table(
    index='Year',
    columns='Sex',
    values='Value',
    aggfunc='mean'
)

ax = england_trend.plot(marker='o')
ax.set_title("Emergency Admissions Over Time in England by Sex")
ax.set_ylabel("Admissions per 100,000")
plt.tight_layout()
plt.show()

# %% [markdown]
# Line Chart  tracking admission rates for males vs females over multple years
#
# The difference is:
#
# *Consistent
#
# *Not random
#
# *Not a one-off year spike
#
# The gap between males and females remains stable across years, indicating a sustained difference rather than a temporary fluctuation.  This suggests systematic differences in healthcare usage,

# %% [markdown]
# Overall insight
#
# Emergency hospital admissions are consistently higher for females in England, and this gap remains stable over time. This indicates that women use emergency healthcare services more frequently than men, which is likely to increase overall healthcare costs through higher resource usage. This supports the idea that healthcare may be more expensive for women not due to higher treatment prices, but because of higher utilisation of high-cost services.

# %% [markdown]
# This dataset does not capture unit treatment cost or outpatient care. Instead, it reflects healthcare demand, which acts as a proxy for cost pressure.
